# %%
f = open('bowlingresult.txt', 'w')
f.write('[//볼링 게임결과 출력값을 텍스트 파일에 넣어야 됨. 해당 내용 추가예정.]')
f.close()

# %%
print("볼링 점수 계산기")

점수 = []

# %%
기본인원수 = 5
기본프레임수 = 10
기본볼링핀수 = 10

인원 = [random.randint(5, 10)]



프레임상태 = {'스페어X':0, '스페어':1, '스트라이크':2}



상태_위치 = {'첫번째투구':0, '두번째투구':1, '세번째투구':2, '상태':3}
프레임별_상태 = [[0,0,0,0] for i in range(기본프레임수)]
프레임별_점수 = [0 for i in range(기본프레임수)]
프레임별_누적점수 = [0 for i in range(기본프레임수)]

# %%
def

# %%
# def 남아있는_핀_개수(핀개수):

# %%
a = [1, "a", [1,2,3]]

# %%
a[0] = 10
print(a)
# Out:
# [10, 'a', [1, 2, 3]]

# %%
b = (1, "a", [1,2,3])

# %%
# b[0] = 10  # 튜플은 내부 아이템 바꾸는 것이 안됨
b[2] [0]= [4,5,6]
print (b)

# %%
print (b)
# Out:
# (1, 'a', [[4, 5, 6], 2, 3])

# %%
c = (0000, [])

# %%
c[1] [0]= ["a"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-258d411b1595> in <cell line: 0>()
# ----> 1 c[1] [0]= ["a"]
#
# IndexError: list assignment index out of range

# %%
str = 'cold'

 # enumerate()
list_enumerate = list(enumerate(str))
print('list(enumerate(str) = ', list_enumerate)
# Out:
# list(enumerate(str) =  [(0, 'c'), (1, 'o'), (2, 'l'), (3, 'd')]

# %%
print('len(str) = ', len(str))
# Out:
# len(str) =  4

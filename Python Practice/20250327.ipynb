# %%
p_list[None, None, None, None, None]
p_count = 0

# %%
p_list = [None, None, None, None, None, None, None, None, None, None]
p_count = 0

while p_count < 10:
    num = int(input("정수를 입력해주세요: "))
    num_c = 0
    for i in range(1, num+1):
        if num > 0:
            num_c = num_c + 1

print(p_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b426aad13eb8> in <cell line: 0>()
#       3
#       4 while p_count < 10:
# ----> 5     num = int(input("정수를 입력해주세요: "))
#       6     num_c = 0
#       7     for i in range(1, num+1):
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
num = int(input('숫자 5개를 입력하세요: '))

res = str.split(',', 10)
if num > 0:
  print("양수입니다.")
else:
  print("음수입니다. 다시 입력하세요.")

print(num)
print(type(num))

# %% [markdown]
# ↓ 정답

# %%
num_list = [None, None, None, None, None]

for index in range(5):
    num_list[index] = int(input("양수 또는 음수를 입력해 주세요 "))

# %%
print(num_list)

# %%
positive = [None, None, None, None, None, None, None, None, None, None]
positive_index = 0

for index in num_list:
  if index >= 0:
    positive[positive_index] = index
    positive_index = positive_index + 1

    if positive_index > 9:
      break
  if index >= 0 and positive_index < 9:
    positive[positive_index] = index
    positive_index = positive_index + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-eb8369405bb1> in <cell line: 0>()
#       3
#       4 for index in num_list:
# ----> 5   if index >= 0:
#       6     positive[positive_index] = index
#       7     positive_index = positive_index + 1
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'int'

# %%
print(positive)
print(positive_index)
# Out:
# [None, None, None, None, None, None, None, None, None, None]
# 0

# %%
# test = list(map(None, range(5)))
# test = list(map(lambda x: None, range(5)))

# %%
print(test)
# Out:
# [None, None, None, None, None]

# %%
positive = [None, None, None, None, None, None, None, None, None, None]
positive_index = 0

while positive_index < 9:
  num_list = [None, None, None, None, None]

    for index in range(5):
        num_list[index] = int(input("양수 또는 음수를 입력해 주세요"))

    for 입력 in num_list:
      if 입력 >= 0 and positive_index < 9:
        positive[positive_index] = index
        positive_index = positive_index + 1
# Out:
#   File "<ipython-input-15-25c63a504339>", line 7
#     for index in range(5):
#     ^
# IndentationError: unexpected indent

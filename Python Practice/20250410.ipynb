# %%
import os
print(os.getcwd()) #/content
print(os.getcwdb())#b'/content’
os.getcwd()
# Out:
# /content
# b'/content'
# '/content'

# %%
path = "makedir_test"
if not os.path.isdir(path):
  os.mkdir(path)

# %%
f=open("c:\test.txt",'w')

# %%
f=open("test.txt", mode='w', encoding='utf-8)

# %%
try:
 f=open("test.txt",encoding='utf-8')
 #performfileoperations
finally:
 f.close()

# %%
with open("c:\test.txt",'w',encoding = 'utf-8') as f:
 f.write("my first file\n")
 f.write("This file\n\n")
 f.write("contains three lines\n")

# %%
f = open("c:\test.txt", encoding='utf-8')

# %%
 f.close()

# %% [markdown]
# ------------------------------------------------------------------------
#
# ---

# %%
# write_data.py
f = open("C\test.txt", 'w')
for i in range(1, 11):
    data = "%d번째 줄입니다.\n" % i
    f.write(data)
f.close()

# %%
f = open('myfile.txt', 'w')
f.write('Hello, Python!')
f.close()

# %%
str = input("키보드를 통해 입력해주세요: ")
print(str)
# Out:
# 키보드를 통해 입력해주세요: "123465789"
# "123465789"

# %%
num = input('숫자를 입력하세요 : ')
print (num)
print (type(num))
# Out:
# 숫자를 입력하세요 : "5"
# "5"
# <class 'str'>

# %%
x1 = 5
y1 = 5

# %%
print(id(5))
print(id(x1))
print(id(y1))
# Out:
# 10750984
# 10750984
# 10750984

# %%
x3 = [1,2,3]
y3 = [1,2,3]
print(id(x3))
print(id(y3))
print(id([1,2,3]))
# Out:
# 140571518304960
# 140571518140928
# 140571518367744

# %%
print(x1 == y1)
print(x3 == y3)
# Out:
# True
# True

# %%
import random

print("성적 처리기 프로그램")
# Out:
# 성적 처리기 프로그램

# %%
성적표 = {}

# %%
for 학년 in range(1, 7): #1~6 학년
  성적표 [str(학년)]
  for 반 in range(1, 6):
    ???????????????????
    for 학생 in range(10):
      국어 = random.randint(0, 100)
      영어 = random.randint(0, 100)
      수학 = random.randint(0, 100)
      성적표 [str(학년)].append({
          "국어": 국어,
          "수학": 수학,
          "영어": 영어
      })

# %%
print("성적을 조회하려면, [학년, 반, 과목] 조건을 입력해주세요. 예시) 4학년 2반 영어")

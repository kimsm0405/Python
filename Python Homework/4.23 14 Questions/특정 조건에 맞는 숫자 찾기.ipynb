# %%
def solution(n):
    result = []
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 2 != 0:
            result.append(i)
    return result


print(solution(20))  # 출력: [3, 9, 15, 21]
# Out:
# [3, 9, 15]

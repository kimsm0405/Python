# %%
def even_sum(n):
    total = 0
    for i in range(2, n + 1, 2):
        total += i
    return total

n = int(input("정수를 입력하세요: "))
result = even_sum(n)
print("짝수의 합:", result)
# Out:
# 정수를 입력하세요: 9
# 짝수의 합: 20

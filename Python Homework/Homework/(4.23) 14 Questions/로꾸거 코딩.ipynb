# %%
def palindrome(a):
    new = a.lower()
    new = new.replace(" ", "")
    return new == new[::-1]


A = input("팰린드롬을 판별할 문자열을 입력하세요 \n")
print(palindrome(A))
# Out:
# 팰린드롬을 판별할 문자열을 입력하세요
# 스위스
# True

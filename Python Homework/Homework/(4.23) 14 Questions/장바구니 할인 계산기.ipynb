# %%
def calculate_total(prices):
    total = 0
    for price in prices:
        if price >= 10000:
            price *= 0.9  # 10% 할인
        total += int(price)  # 소수점 제거
    return total


prices = [12000, 8000, 15000, 5000]
total = calculate_total(prices)
print("지불 금액:", total)
